# %%
import requests
import pandas as pd 
from yahoo_fin import stock_info as si 
from pandas_datareader import DataReader
import numpy as np
import time

tickers = si.tickers_sp500()
recommendations = []

for ticker in tickers:
    lhs_url = 'https://query2.finance.yahoo.com/v10/finance/quoteSummary/'
    rhs_url = '?formatted=true&crumb=swg7qs5y9UP&lang=en-US&region=US&' \
              'modules=upgradeDowngradeHistory,recommendationTrend,' \
              'financialData,earningsHistory,earningsTrend,industryTrend&' \
              'corsDomain=finance.yahoo.com'
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    url =  lhs_url + ticker + rhs_url
    r = requests.get(url, headers=headers)
    if not r.ok:
        recommendation = 6
    try:
        result = r.json()['quoteSummary']['result'][0]
        recommendation =result['financialData']['recommendationMean']['fmt']
    except:
        recommendation = 6
    
    recommendations.append(recommendation)
    
    #print("--------------------------------------------")
    #print ("{} has an average recommendation of: ".format(ticker), recommendation)
    if float(recommendation) < 2:
        print(f"{ticker} has an average recommendation of: {recommendation}")
    time.sleep(0.5)
    
dataframe = pd.DataFrame(list(zip(tickers, recommendations)), columns =['Company', 'Recommendations']) 
dataframe = dataframe.set_index('Company')
dataframe.to_csv('recommendations.csv')

print (dataframe)
# Out:
# AAPL has an average recommendation of: 1.90
# ABT has an average recommendation of: 1.90
# ADBE has an average recommendation of: 1.80
# ADI has an average recommendation of: 1.90
# ADM has an average recommendation of: 1.80
# AES has an average recommendation of: 1.70
# AIZ has an average recommendation of: 1.60
# ALGN has an average recommendation of: 1.90
# ALK has an average recommendation of: 1.80
# AMP has an average recommendation of: 1.90
# AMZN has an average recommendation of: 1.70
# ANTM has an average recommendation of: 1.90
# ARE has an average recommendation of: 1.60
# ATVI has an average recommendation of: 1.80
# BIO has an average recommendation of: 1.50
# BLK has an average recommendation of: 1.90
# BMY has an average recommendation of: 1.90
# BSX has an average recommendation of: 1.80
# CMCSA has an average recommendation of: 1.90
# CNC has an average recommendation of: 1.80
# COP has an average recommendation of: 1.80
# CPRT has an average recommendation of: 1.70
# CRL has an average recommendation of: 1.70
# CRM has an average recommendation of: 1.80
# CTLT has an average recommendation of: 1.60
# CZR has an average recommendation of: 1.90
# DG has an average recommendation of: 1.90
# DHI has an average recommendation of: 1.80
# DHR has an average recommendation of: 1.90
# DVN has an average recommendation of: 1.80
# DXCM has an average recommendation of: 1.60
# EQIX has an average recommendation of: 1.80
# ETSY has an average recommendation of: 1.90
# FANG has an average recommendation of: 1.80
# FB has an average recommendation of: 1.90
# FIS has an average recommendation of: 1.90
# FISV has an average recommendation of: 1.80
# FITB has an average recommendation of: 1.90
# GLW has an average recommendation of: 1.90
# GM has an average recommendation of: 1.70
# GNRC has an average recommendation of: 1.60
# GOOG has an average recommendation of: 1.60
# GOOGL has an average recommendation of: 1.70
# GPN has an average recommendation of: 1.90
# HAS has an average recommendation of: 1.90
# HOLX has an average recommendation of: 1.70
# ICE has an average recommendation of: 1.90
# INFO has an average recommendation of: 1.90
# INTU has an average recommendation of: 1.80
# IQV has an average recommendation of: 1.60
# IR has an average recommendation of: 1.90
# J has an average recommendation of: 1.70
# KMX has an average recommendation of: 1.80
# LDOS has an average recommendation of: 1.80
# LH has an average recommendation of: 1.70
# LIN has an average recommendation of: 1.90
# LKQ has an average recommendation of: 1.50
# LOW has an average recommendation of: 1.90
# LW has an average recommendation of: 1.70
# MA has an average recommendation of: 1.80
# MCK has an average recommendation of: 1.90
# MDT has an average recommendation of: 1.90
# MPC has an average recommendation of: 1.80
# MPWR has an average recommendation of: 1.80
# MSFT has an average recommendation of: 1.70
# MSI has an average recommendation of: 1.80
# MU has an average recommendation of: 1.90
# NI has an average recommendation of: 1.90
# NKE has an average recommendation of: 1.90
# NOW has an average recommendation of: 1.70
# NWSA has an average recommendation of: 1.90
# PAYC has an average recommendation of: 1.80
# PLD has an average recommendation of: 1.90
# PTC has an average recommendation of: 1.90
# PWR has an average recommendation of: 1.90
# PXD has an average recommendation of: 1.90
# PYPL has an average recommendation of: 1.80
# QCOM has an average recommendation of: 1.90
# RJF has an average recommendation of: 1.80
# RTX has an average recommendation of: 1.90
# SBAC has an average recommendation of: 1.80
# SPGI has an average recommendation of: 1.70
# STE has an average recommendation of: 1.60
# TDY has an average recommendation of: 1.90
# TECH has an average recommendation of: 1.80
# TGT has an average recommendation of: 1.90
# TJX has an average recommendation of: 1.90
# TMO has an average recommendation of: 1.80
# TMUS has an average recommendation of: 1.90
# TYL has an average recommendation of: 1.90
# UNH has an average recommendation of: 1.80
# V has an average recommendation of: 1.80
# VLO has an average recommendation of: 1.90
# WMB has an average recommendation of: 1.90
# WY has an average recommendation of: 1.90
# ZBH has an average recommendation of: 1.90
# ZTS has an average recommendation of: 1.70
#         Recommendations
# Company
# A                     6
# AAL                3.10
# AAP                2.20
# AAPL               1.90
# ABBV               2.00
# ...                 ...
# YUM                2.60
# ZBH                1.90
# ZBRA               2.20
# ZION               2.70
# ZTS                1.70
#
# [505 rows x 1 columns]

# %%
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 688 kB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: lxml in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: pandas>=0.23 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas-datareader) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.4)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
